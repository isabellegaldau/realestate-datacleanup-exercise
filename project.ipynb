# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
# TODO

#finding highest price in list

most_expensive = ds['price'].max()
print(most_expensive)

#finding index

max_index = ds['price'].idxmax()
print(max_index)

#finding address
location = ds.loc[max_index,'address']
print(location)

print(f"The house with address {location} is the most expensive and its price is {most_expensive} USD.")
# Out:
# 8500000
# 13110
# El Escorial
# The house with address El Escorial is the most expensive and its price is 8500000 USD.

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO

#finding lowest price in list

least_expensive = ds['price'].min()
print(least_expensive)

#finding index

min_index = ds['price'].idxmin()
print(min_index)

#finding address
location = ds.loc[min_index,'address']
print(location)

print(f"The house with address {location} is the cheapest and its price is {least_expensive} USD.")
# Out:
# 0
# 366
# Parla
# The house with address Parla is the cheapest and its price is 0 USD.

# %%
# Exclude zero prices and find the lowest price greater than 0
least_expensive = ds.loc[ds['price'] > 0, 'price'].min()
print(least_expensive)

# Find the index of the minimum price greater than 0
min_index = ds.loc[ds['price'] > 0, 'price'].idxmin()
print(min_index)

# Find the address corresponding to the minimum price greater than 0
location = ds.loc[min_index, 'address']
print(location)

print(f"The house with address {location} is the cheapest and its price is {least_expensive} USD.")
# Out:
# 600
# 7491
# Berlin, Coslada
# The house with address Berlin, Coslada is the cheapest and its price is 600 USD.

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO

#finding biggest & smallest in list

biggest = ds['surface'].max()
print(biggest)
smallest = ds['surface'].min()
print(smallest)

#finding index

big_index = ds['surface'].idxmax()
print(big_index)
small_index = ds['surface'].idxmin()
print(small_index)

#finding address
location_big = ds.loc[big_index,'address']
print(location_big)
location_small = ds.loc[small_index,'address']
print(location_small)

print(f"The house with address {location_big} is the biggest and its surface area is {biggest} meters.")
print(f"The house with address {location_small} is the smallest and its surface area is {smallest} meters.")
# Out:
# 249000.0
# 15.0
# 6794
# 498
# Sevilla la Nueva
# Calle Amparo,  Madrid Capital
# The house with address Sevilla la Nueva is the biggest and its surface area is 249000.0 meters.
# The house with address Calle Amparo,  Madrid Capital is the smallest and its surface area is 15.0 meters.

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
population_names = ds['level5'].unique()

names_str = ', '.join(population_names)

print("Populations:", names_str)
print(population_names)
# Out:
# Populations: Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
# TODO


nas_in_columns = ds.isna().any()
print(nas_in_columns)
# print("Columns with NAs:")
# for column, has_nas in nas_in_columns.items():
#     print(f"{column}: {has_nas}")
# Out:
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# ...

# %%
print(ds.isna())
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
# TODO

ds_clean = ds.dropna()
print(f'The dimensions of the Data Frame after deletions is {ds_clean.shape} which is completely null compared to the original {ds.shape}')
print(ds_clean.shape, ds.shape)
# Out:
# The dimensions of the Data Frame after deletions is (0, 37) which is completely null compared to the original (15335, 37)
# (0, 37) (15335, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
# TODO

# Locate only Arroyomolinos (Madrid) prices
Arroyomolinos_prices = ds[ds['level5'] == 'Arroyomolinos (Madrid)']['price']

# Calculate the mean
average_price = Arroyomolinos_prices.mean()
average_price_dollars = "{:.2f}".format(average_price)

# Print the average price 
print(f"The average price of listings in Arroyomolinos (Madrid) is {average_price_dollars} USD")
# Out:
# The average price of listings in Arroyomolinos (Madrid) is 294541.60 USD

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code

# Data
Arroyomolinos_prices = ds[ds['level5'] == 'Arroyomolinos (Madrid)']['price']


# Plot histogram
Arroyomolinos_prices.hist(bins=5, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Price (USD)')
plt.ylabel('Listings')
plt.title('Arroyomolinos (Madrid)')

# Show plot
plt.show()

# %% [markdown]
# **TODO: Markdown**. It seems the prices in this Population follow a normal distribution, with most listings concentrated around the 300k mark.

# %% [markdown]
# #### Exercise 09. Are the averages of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
# TODO

#Valdemorillo mean
Valdemorillo_prices = ds[ds['level5'] == 'Valdemorillo']['price']
v_average_price = Valdemorillo_prices.mean()
v_average_price_dollars = "{:.2f}".format(v_average_price)
print(f'Valdemorillo mean listing price: {v_average_price_dollars} USD')

#Valdemorillo mean
Galapagar_prices = ds[ds['level5'] == 'Galapagar']['price']
g_average_price = Galapagar_prices.mean()
g_average_price_dollars = "{:.2f}".format(g_average_price)
print(f'Galapagar mean listing price: {g_average_price_dollars} USD')
# Out:
# Valdemorillo mean listing price: 363860.29 USD
# Galapagar mean listing price: 360063.20 USD

# %% [markdown]
# **TODO: Markdown**. Valdemorillo listings seem to average at a marginally higher price point than Galapagar listings. This difference however doesnt substantiate a different socio economic deomgrahpic.

# %% [markdown]
# #### Exercise 10. Are the averages of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO

#Creating column PPS
ds['pps'] = ds['price'] / ds['surface']

#Valdemorillo PPS mean
Valdemorillo_pps = ds[ds['level5'] == 'Valdemorillo']['pps']
v_average_pps = Valdemorillo_pps.mean()
print(F'Valdemorillo PPS: {v_average_pps}')

#Galapagar PPS mean
Galapagar_pps = ds[ds['level5'] == 'Galapagar']['pps']
g_average_pps = Galapagar_pps.mean()
print(f'Galapagar PPS: {g_average_pps}')
# Out:
# Valdemorillo PPS: 1317.9502109024986
# Galapagar PPS: 1606.3240303094024

# %% [markdown]
# **TODO: Markdown**. Interestingly, analysing the surface area to price ratio of the two populations, Valdemorillo listings defintely offer more 'bang for your buck', being signifcantly cheaper than Galapagar. This would indicate marketability to two different clientelle.

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %% [markdown]
# STUDENTS NOTE: I wasnt sure if this question called for a scatter plot for just the two populations in the previous question or for all the populations so i did both!!

# %%
# List of specific Populations
filtered_values = ["Valdemorillo","Galapagar"]

# Creating subset
filtered_ds = ds[ds['level5'].isin(filtered_values)]

plt.figure(figsize=(8, 6))
plt.scatter(filtered_ds['surface'], filtered_ds['price'], alpha=0.5)
plt.title('Relationship Between Surface Area and Price of Houses')
plt.xlabel('Surface Area')
plt.ylabel('Price ($)')
plt.grid(True)
plt.show()

# %%
# dropping biggest outliers
biggest_outliers = ds.nlargest(3, 'surface')
ds_scatter1 = ds.drop(biggest_outliers.index)

#plotting
plt.figure(figsize=(8, 6))
plt.scatter(ds_scatter1['surface'], ds_scatter1['price'], alpha=0.5, s= 1)
plt.title('Relationship Between Surface Area and Price of Houses')
plt.xlabel('Surface Area')
plt.ylabel('Price ($)')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Dropping the biggest outliers
biggest_outliers = ds.nlargest(3, 'surface')
ds_scatter1 = ds.drop(biggest_outliers.index)

# Plotting the scatter plot with a trend line
plt.figure(figsize=(8, 6))
sns.regplot(x='surface', y='price', data=ds_scatter1, scatter_kws={'s': 1, 'alpha': 0.5}, line_kws={'color': 'red'})

# Adding title and labels
plt.title('Relationship Between Surface Area and Price of Houses')
plt.xlabel('Surface Area')
plt.ylabel('Price ($)')
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# **TODO: Markdown**. At a stretch, there seems to be a positive correlation between Surface Area and Price of homes

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
# TODO

agency_counts = ds['realEstate_name'].value_counts()
print(f"The data set contains {len(agency_counts)} agencies.")
# Out:
# The data set contains 1821 agencies.

# %%
# Using the `nunique` method to count the number of unique agencies
num_agencies = ds['realEstate_name'].nunique()
print(f"The data set contains {num_agencies} agencies.")
# Out:
# The data set contains 1821 agencies.

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# TODO

population_counts = ds['level5'].value_counts()
print(f'{population_counts.idxmax()}: {population_counts.max()} listings')
# Out:
#  Madrid Capital: 6643 listings

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# TODO



# List of specific Populations
specific_values = ["Fuenlabrada","Leganés","Getafe","Alcorcón"]

# Creating subset
subset_ds = ds[ds['level5'].isin(specific_values)]

print(subset_ds)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
# TODO: Code


median_values = subset_ds.groupby('level5')['price'].median()

# Plot bar plot
median_values.plot(kind='bar', color='pink', edgecolor='black')

# Add labels and title
plt.xlabel('Populations')
plt.ylabel('Median Price')
plt.title('Bar Plot of Median Prices')

# Show plot
plt.show()

# %% [markdown]
# **TODO: Markdown**. Getafe surpasses the other populations in the subset substatially, offering a median succeeding the approximate 270k mark. The rest of the populations are nicely comparable around the 150-160k mark.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# TODO
#price
price_mean = subset_ds['price'].mean()
price_var = subset_ds['price'].var()
print(f'Price Mean: {price_mean}')
print(f'Price Variance: {price_var}')

#rooms
rooms_mean =  subset_ds['rooms'].mean()
rooms_var = subset_ds['rooms'].var()
print(f'Rooms Mean: {rooms_mean}')
print(f'Rooms Variance: {rooms_var}')

#surface area
surface_mean =  subset_ds['surface'].mean()
surface_var = subset_ds['surface'].var()
print(f'Surface Mean: {surface_mean}')
print(f'Surface Variance: {surface_var}')

#bathrooms
b_mean =  subset_ds['bathrooms'].mean()
b_var = subset_ds['bathrooms'].var()
print(f'Bathrooms Mean: {b_mean}')
print(f'Bathrooms Variance: {b_var}')
# Out:
# Price Mean: 223094.48070562293
# Price Variance: 14921367508.04902
# Rooms Mean: 3.0177383592017737
# Rooms Variance: 0.7188858892927542
# Surface Mean: 111.75222363405337
# Surface Variance: 4263.051760316337
# Bathrooms Mean: 1.633221850613155
# Bathrooms Variance: 0.5717968625577321

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# TODO

#fuenlabrada max
alcorcon_prices = subset_ds[subset_ds['level5'] == 'Alcorcón']['price']
alcorcon_max = alcorcon_prices.max()
#finding index
max_index_a = alcorcon_prices.idxmax()
#finding address
location_a = subset_ds.loc[max_index_a,'address']

print(f"Alcorcón: The house with address {location_a} is the most expensive and its price is {alcorcon_max} USD.")


#fuenlabrada max
fuenlabrada_prices = subset_ds[subset_ds['level5'] == 'Fuenlabrada']['price']
fuenlabrada_max = fuenlabrada_prices.max()
#finding index
max_index_f = fuenlabrada_prices.idxmax()
#finding address
location_f = subset_ds.loc[max_index_f,'address']

print(f"Fuenlabrada: The house with address {location_f} is the most expensive and its price is {fuenlabrada_max} USD.")

#getafe max
getafe_prices = subset_ds[subset_ds['level5'] == 'Getafe']['price']
getafe_max = getafe_prices.max()
#finding index
max_index_g = getafe_prices.idxmax()
#finding address
location_g = subset_ds.loc[max_index_g,'address']

print(f"Getafe: The house with address {location_g} is the most expensive and its price is {getafe_max} USD.")

#leganes max
leganes_prices = subset_ds[subset_ds['level5'] == 'Leganés']['price']
leganes_max = leganes_prices.max()
#finding index
max_index_l = leganes_prices.idxmax()
#finding address
location_l = subset_ds.loc[max_index_l,'address']

print(f"Leganes: The house with address {location_l} is the most expensive and its price is {leganes_max} USD.")
# Out:
# Alcorcón: The house with address Alcorcón is the most expensive and its price is 950000 USD.
# Fuenlabrada: The house with address Calle de Paulo Freire, 5, Fuenlabrada is the most expensive and its price is 490000 USD.
# Getafe: The house with address Getafe is the most expensive and its price is 1050000 USD.
# Leganes: The house with address Avenida Reina Sofía, Leganés is the most expensive and its price is 650000 USD.

# %%
# Sort the subset by 'level5' (populations) and 'price' in descending order
sorted_subset = subset_ds.sort_values(by=['level5', 'price'], ascending=[True, False])

# Drop duplicates to keep only the most expensive house per population
most_expensive_houses = sorted_subset.drop_duplicates(subset='level5', keep='first')

# Print the address and price of the most expensive house for each population
for index, row in most_expensive_houses.iterrows():
    print(f"Population: {row['level5']}, Address: {row['address']}, Price: {row['price']}")
# Out:
# Population: Alcorcón, Address: Alcorcón, Price: 950000
# Population: Fuenlabrada, Address: Calle de Paulo Freire, 5, Fuenlabrada, Price: 490000
# Population: Getafe, Address: Getafe, Price: 1050000
# Population: Leganés, Address: Avenida Reina Sofía, Leganés, Price: 650000

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# Create function to normalize prices for each group
def normalized_prices(group):
    return (group - group.min()) / (group.max() - group.min())

# Normalized price for each population
normalized_data = subset_ds.groupby('level5')['price'].transform(normalized_prices)

# Add normalized data back to the original DataFrame for plotting
subset_ds['normalized_price'] = normalized_data

# Plot histograms for normalized prices of each population
plt.figure(figsize=(10, 6))
for population, group in subset_ds.groupby('level5'):
    plt.hist(group['normalized_price'], bins=20, alpha=0.5, label=population)

plt.title('Normalized Price Distribution for Each Population')
plt.xlabel('Normalized Price')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_737/928310832.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_ds['normalized_price'] = normalized_data

# %%
subset = ds[ds['level5'].isin(['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón'])]

subset['normalized_price'] = subset.groupby('level5')['price'].transform(lambda x:  (x - x.mean()) / x.std())

plt.figure(figsize=(10, 6))

subset['level5'].unique()
plt.hist(subset[subset['level5'] == 'level5'] ['normalized_price'], bins=30, alpha=0.5, label=population)

plt.title('Histograms of Normalized Prices by Population')
# Out:
# /tmp/ipykernel_737/1244696414.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['normalized_price'] = subset.groupby('level5')['price'].transform(lambda x:  (x - x.mean()) / x.std())
# Text(0.5, 1.0, 'Histograms of Normalized Prices by Population')

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO

#Getafe PPS mean
getafe_pps = subset_ds[subset_ds['level5'] == 'Getafe']['pps']
print(F'Getafe PPS: {getafe_pps.mean()}')

#Alcorcón PPS mean
alcorcon_pps = subset_ds[subset_ds['level5'] == 'Alcorcón']['pps']
print(F'Alcorcón PPS: {alcorcon_pps.mean()}')
# Out:
# Getafe PPS: 2066.314949251463
# Alcorcón PPS: 2239.302480199618

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# TODO
#"Fuenlabrada","Leganés","Getafe","Alcorcón" 
 
f_surface = subset_ds[subset_ds['level5'] == 'Fuenlabrada']['surface']
l_surface = subset_ds[subset_ds['level5'] == 'Leganés']['surface']
g_surface = subset_ds[subset_ds['level5'] == 'Getafe']['surface']
a_surface = subset_ds[subset_ds['level5'] == 'Alcorcón']['surface']

f_y_data = subset_ds[subset_ds['level5'] == 'Fuenlabrada']['price']
l_y_data = subset_ds[subset_ds['level5'] == 'Leganés']['price']
g_y_data = subset_ds[subset_ds['level5'] == 'Getafe']['price']
a_y_data = subset_ds[subset_ds['level5'] == 'Alcorcón']['price']

# Create subplots
f, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot each set of x and y variables on separate subplots
axs[0, 0].scatter(f_surface, f_y_data, color='blue', label='Fuenlabrada')
axs[0, 1].scatter(l_surface, l_y_data, color='red', label='Leganes')
axs[1, 0].scatter(g_surface, g_y_data, color='green', label='Getafe')
axs[1, 1].scatter(a_surface, a_y_data, color='orange', label='Alcorcon')

# Add labels and legend to each subplot
for ax in axs.flat:
    ax.set(xlabel='Surface', ylabel='Price')
    ax.legend()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centered on Madrid (40.4168° N, -3.7038° W)
map = Map(
    center=(40.32, -3.8),
    zoom=12,  # Adjust zoom level for a closer view of Madrid
    min_zoom=1,
    max_zoom=20,
    basemap=basemaps.OpenStreetMap.Mapnik
)

map
# Out:
# Map(center=[40.32, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
# Select relevant columns
subset_map_ds = subset_ds[['level5', 'latitude', 'longitude']]

# Replace commas with periods in the latitude and longitude columns
subset_map_ds['latitude'] = subset_map_ds['latitude'].str.replace(',', '.')
subset_map_ds['longitude'] = subset_map_ds['longitude'].str.replace(',', '.')

# Convert latitude and longitude columns to float
subset_map_ds['latitude'] = subset_map_ds['latitude'].astype(float)
subset_map_ds['longitude'] = subset_map_ds['longitude'].astype(float)
# Out:
# /tmp/ipykernel_737/492667608.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_map_ds['latitude'] = subset_map_ds['latitude'].str.replace(',', '.')
# /tmp/ipykernel_737/492667608.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_map_ds['longitude'] = subset_map_ds['longitude'].str.replace(',', '.')
# /tmp/ipykernel_737/492667608.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from ipyleaflet import Map, basemaps, CircleMarker
import pandas as pd


# Create the map centered on the south-west of Madrid with the appropriate zoom level
madrid_map = Map(center=(40.32, -3.8), zoom=12, min_zoom=1, max_zoom=20, basemap=basemaps.OpenStreetMap.Mapnik)

# Define colors for each population
colors = {
    "Fuenlabrada": "blue",
    "Leganés": "green",
    "Getafe": "red",
    "Alcorcón": "orange"
}

# Add circle markers to the map for each population directly from the DataFrame
for idx, row in subset_map_ds.iterrows():
    population = row['level5']
    coord = (row['latitude'], row['longitude'])
    circle_marker = CircleMarker(
        location=coord,
        radius=5,  # Set radius of the circle marker
        color=colors.get(population, 'gray'),  # Fallback color if population not in 'colors'
        fill_color=colors.get(population, 'gray'),
        fill_opacity=0.6
    )
    madrid_map.add_layer(circle_marker)

# Display the map
madrid_map
# Out:
# Map(center=[40.32, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
import folium
from folium import CircleMarker
import pandas as pd

# Filter the data for specific values in 'level5'
ds2 = ds[ds['level5'].isin(specific_values)]

# Correct the replacement of commas in latitude and longitude
ds2['latitude'] = ds2['latitude'].str.replace(',', '.').astype(float)
ds2['longitude'] = ds2['longitude'].str.replace(',', '.').astype(float)

# Create the map centered around Madrid
madrid_map = folium.Map(location=[40.416775, -3.703790], zoom_start=11)

# Define colors for specific populations
colors = {
    'Getafe': 'blue',
    'Alcorcón': 'green',
    'Fuenlabrada': 'red',
    'Leganés': 'purple'
}

# Add circle markers to the map for each row in the filtered DataFrame
for idx, row in ds2.iterrows():
    population = row['level5']
    coord = (row['latitude'], row['longitude'])
    circle_marker = CircleMarker(
        location=coord,
        radius=5,
        color=colors.get(population, 'gray'),  # Fallback to 'gray' if population not in 'colors'
        fill=True,
        fill_color=colors.get(population, 'gray'),
        fill_opacity=0.6
    )
    circle_marker.add_to(madrid_map)

# Save the map to an HTML file
madrid_map.save('madrid_south_belt_map.html')

# Display the map
madrid_map
# Out:
# /tmp/ipykernel_737/279755244.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds2['latitude'] = ds2['latitude'].str.replace(',', '.').astype(float)
# /tmp/ipykernel_737/279755244.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds2['longitude'] = ds2['longitude'].str.replace(',', '.').astype(float)
# ...
