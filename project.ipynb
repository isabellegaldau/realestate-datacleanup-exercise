# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd
import numpy as np

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
expensive_index = ds['price'].idxmax()
expensive_value = ds.loc[expensive_index, 'price']
expensive_address = ds.loc[expensive_index, 'address']


print(f"The house with {expensive_address} is the most expensive and its price is {expensive_value} USD")
# Out:
# The house with El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cheap_index = ds['price'].idxmin()
cheapest_value = ds.loc[cheap_index, 'price']
cheapest_address = ds.loc[cheap_index, 'address']


print(f"The house with address {cheapest_address} is the cheapest and its price is {cheapest_value} USD")
# Out:
# The house with address Parla is the cheapest and its price is 0 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
biggest_index = ds['surface'].idxmax()
size_big = ds.loc[biggest_index, 'surface']
address_big = ds.loc[biggest_index, 'address']

smallest_index = ds['surface'].idxmin()
size_small = ds.loc[smallest_index, 'surface']
address_small = ds.loc[smallest_index, 'address']

print(f"The bigger house is located on {address_big} and its surface is {size_big} meters")
print(f"The smaller house is located on {address_small} and its surface is {size_small} meters")
# Out:
# The bigger house is located on Sevilla la Nueva and its surface is 249000.0 meters
# The smaller house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
biggest = ds['surface'].max()
biggest_surface = ds[ds['surface']==ds['surface'].max()]
print(biggest)
print(biggest_surface)
# Out:
# 249000.0
#       Unnamed: 0  id_realEstates  isNew          realEstate_name  \
# 6794        6795       153936192  False  habitarium inmobiliaria
#
#       phone_realEstate                                       url_inmueble  \
# 6794       916357732.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#       rooms  bathrooms   surface   price  ... level4Id level5Id level6Id  \
# 6794    3.0        2.0  249000.0  289000  ...        0        0        0
#
#      level7Id level8Id accuracy  latitude longitude zipCode customZone
# 6794        0        0        0  40,34633  -4,02174     NaN        NaN
#
# [1 rows x 37 columns]

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
# TODO 
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
populations = set()

for population in ds['level5']:
    if population not in populations:
        populations.add(population)

print(", ".join(populations))
# Out:
# Titulcia, Brunete, Torrelodones, Manzanares El Real, Aldea del Fresno, Los Santos de la Humosa, Batres, Estremera, Collado Villalba, Ciempozuelos, Becerril de la Sierra, Puentes Viejas, San Lorenzo de El Escorial, Valdetorres de Jarama, Bustarviejo, Collado Mediano, Fuenlabrada, Cercedilla, Arganda del Rey, Navalagamella, Guadalix de la Sierra, Guadarrama, Móstoles, El Escorial, Miraflores de la Sierra, Venturada, Valdepiélagos, Pozuelo de Alarcón, Gascones, Cobeña, Camarma de Esteruelas, Pinilla del Valle, Ribatejada, Ambite, Torrejón de la Calzada, Braojos, Villamanrique de Tajo, Fuentidueña de Tajo, Sevilla la Nueva, Cenicientos, Villa del Prado, Velilla de San Antonio, Fuente El Saz de Jarama, Leganés, Ajalvir, Pinto, Mejorada del Campo, Valdaracete, Soto del Real, Gargantilla del Lozoya, Alcorcón, Fresno de Torote - Serracines, Torremocha de Jarama, Brea de Tajo, Montejo de la Sierra, Lozoya, Aranjuez, Cadalso de los Vidrios, Griñón, Valdemorillo, Villar del Olmo, Talamanca de J
# ...

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
populations = ds['level5'].unique()

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')

ds_nan = ds.isna()

ds_nan.head()
# Out:
#    Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0       False           False  False            False             False
# 1       False           False  False            False             False
# 2       False           False  False            False             False
# 3       False           False  False            False             False
# 4       False           False  False            False             False
#
#    url_inmueble  rooms  bathrooms  surface  price  ...  level4Id  level5Id  \
# 0         False  False      False    False  False  ...     False     False
# 1         False  False      False     True  False  ...     False     False
# 2         False  False      False    False  False  ...     False     False
# 3         False  False      False    False  False  ...     False     False
# 4         False  False      False    False  False  ...     False     False
#
#    level6Id  level7Id  level8Id  accuracy  latitude  longitude  zipCode  \
# ...

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')

ds_nan = ds.isna().sum()
print(ds_nan)
# Out:
# Unnamed: 0              0
# id_realEstates          0
# isNew                   0
# realEstate_name        10
# phone_realEstate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                    0
# description           142
# address                 0
# country                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperLevel              0
# countryId               0
# level1Id                0
# level2Id                0
# level3Id                0
# level4Id                0
# level5Id                0
# level6Id                0
# level7Id                0
# level8Id                0
# accuracy                0
# latitude                0
# longitude               0
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
nan_columns = ds.columns[ds.isna().any()]
print(nan_columns)
# Out:
# Index(['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface',
#        'description', 'level4', 'level6', 'level7', 'level8', 'zipCode',
#        'customZone'],
#       dtype='object')

# %%
columns_delete = ds.columns[ds.isna().sum()>1251]
ds_clean_columns = ds.drop(columns=columns_delete)
ds_clean_columns.shape, ds.shape
# Out:
# ((15335, 31), (15335, 37))

# %%
# TODO
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds_nan = ds.isna()
ds_clean = ds_clean_columns.dropna(axis=0)
print(ds_clean)


size_of_ds_clean_rows = ds_clean.shape
size_of_ds = ds.shape
print(size_of_ds_clean_rows)
print(size_of_ds)
print(f'The size of the original data frame is {size_of_ds} which is larger in comparison to its dimensions after the deletion of NaN values {size_of_ds_clean_rows}')
print(ds_clean.isna().sum())
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# 5               6       153934794  False                            expimad
# ...           ...             ...    ...                                ...
# 15329       15330       153901392  False                           pqcentro
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
# TODO  

madrid_mean_population = ds_clean[ds_clean['level5']=="Arroyomolinos (Madrid)"]['price'].mean()
print(madrid_mean_population)
# Out:
# 298780.2181818182

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code
import matplotlib.pyplot as plt


madrid_population = ds_clean[ds_clean['level5']=="Arroyomolinos (Madrid)"]
bins = (100000, 200000, 300000, 400000, 500000, 600000, 700000)
plt.hist(madrid_population['price'], bins= bins, color = '#cc33ff' )
plt.xlabel('Prices in USD')
plt.ylabel('Houses on Market')
plt.xticks(bins)
#plt.ylabel()
plt.title('Histogram of prices of Arroyomolinos (Madrid)')
plt.show()

# %% [markdown]
# **TODO: Markdown**
#
# Observations: From the chart above we can extrapolate that the average prices for homes in Arroyomolinos are concetrated in the 200-400k range.

# %% [markdown]
# #### Exercise 09. Is the average of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
# TODO

valdemorillo_mean = ds_clean[ds_clean['level5']=="Valdemorillo"]['price'].mean()
galapagar_mean = ds_clean[ds_clean['level5']=="Galapagar"]['price'].mean()

print(valdemorillo_mean, galapagar_mean)
print(f'The average prices of Valdemorillo, at {valdemorillo_mean} USD stand only marginally higher than that of Galapagars, being, in comparison {galapagar_mean} USD. This would make them similarly accesible areas in the Real Estate market.')
# Out:
# 384269.5652173913 381106.70149253734
# The average prices of Valdemorillo, at 384269.5652173913 USD stand only marginally higher than that of Galapagars, being, in comparison 381106.70149253734 USD. This would make them similarly accesible areas in the Real Estate market.

# %% [markdown]
# The average prices of Valdemorillo, at appx 384K USD stand only marginally higher than that of Galapagars, being, in comparison 381k USD. This would make them similarly accesible areas in the Real Estate market.

# %% [markdown]
# #### Exercise 10. Is the average of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
#Step 1

ds_clean['pps'] = ds_clean['price'].div(ds_clean['surface'])
ds_clean.head()
# Out:
# /tmp/ipykernel_882/3732520378.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_clean['pps'] = ds_clean['price'].div(ds_clean['surface'])
#    Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0           1       153771986  False            ferrari 57 inmobiliaria
# 2           3       153430440  False                 look find boadilla
# 3           4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           5       153180188  False            ferrari 57 inmobiliaria
# 5           6       153934794  False                            expimad
#
#    phone_realEstate                                       url_inmueble  rooms  \
# ...

# %%
#Step 2

valdemorillo_mean_pps = ds_clean[ds_clean['level5']=="Valdemorillo"]['pps'].mean()
galapagar_mean_pps = ds_clean[ds_clean['level5']=="Galapagar"]['pps'].mean()
print(valdemorillo_mean_pps, galapagar_mean_pps)
# Out:
# 1321.766036146825 1566.51539198496

# %% [markdown]
# We can note that the Valdemorillo housing market offers on average more floor space by the dollar, making it perhaps more desirable for those who seek more spacious facilities.

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
# TODO: Code

import numpy as np
import matplotlib.pyplot as plt
ds_clean = ds_clean[ds_clean['surface']< 50000]
x = ds_clean['surface']
y = ds_clean['price']
plt.scatter(x,y, color = '#cc33ff')
plt.show()

# %% [markdown]
# **TODO: Markdown**.
#
# Observations:
# Apart from the few occuring outliers, spanning otside the range of 50,000 removed for data comrehesion, The scatter plot indicates a somewhat congruent correlation of price to floor area relation. The outliers can be speculated to be caused by several variables, common in the housing market, such as a premium location, variance in property type, extra/luxury facilites... etc.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
# TODO
agency_names  = ds_clean['realEstate_name'].unique()
number_of_agencies = len(agency_names)
print(number_of_agencies)
# Out:
# 1443

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# TODO

population_counts = ds_clean['level5'].value_counts()
population_mogul = population_counts.idxmax()
population_mogul_houses = population_counts.max()
print(population_mogul, population_mogul_houses)
#print(population_counts)
# Out:
#  Madrid Capital 5658

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# TODO
subset_ds = ds_clean[ds_clean['level5'].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]
subset_ds.head()
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 94           95       153995577  False                    viviendas365com
# 109         110       153586414  False    area uno asesores inmobiliarios
# 161         162       153440116  False                          prolucisa
# 169         170       153920011  False                       grupo tizona
#
#      phone_realEstate                                       url_inmueble  \
# 3         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 94        911226014.0  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 161       916350416.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 169       911226046.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#      rooms  bathrooms  surface   price  ... level3Id level4Id level5Id  \
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
# TODO: Code


median_prices = subset_ds.groupby('level5')['price'].median().reset_index()
print(median_prices['level5'])

plt.bar(median_prices['level5'],median_prices['price'], color = '#cc33ff' )
plt.xlabel('populations')
plt.ylabel('median prices')
plt.title('Median Prices for Each Population', fontdict = {'fontweight' : 'bold'})
plt.show()
# Out:
# 0       Alcorcón
# 1    Fuenlabrada
# 2         Getafe
# 3        Leganés
# Name: level5, dtype: object

# %% [markdown]
# **TODO: Markdown**.
#
# Observations:
#
# We can see that on average, the Median Prices float congruently between the 150-180k range, apart from the Getafe median, marking an impressive 250k median.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# TODO
#subset_ds.describe()
mean_price = subset_ds['price'].mean()
var_price = subset_ds['price'].var()
print("Price mean and variance:")
print(mean_price,var_price)

mean_rms = subset_ds['rooms'].mean()
var_rms = subset_ds['rooms'].var()
print("Room mean and variance:")
print(mean_rms, var_rms)

mean_sf = subset_ds['surface'].mean()
var_sf = subset_ds['surface'].var()
print("Surface Area mean and variance:")
print(mean_sf, var_sf)

mean_br = subset_ds['bathrooms'].mean()
var_br = subset_ds['bathrooms'].var()
print("Bedroom mean and variance:")
print(mean_br, var_br)
# Out:
# Price mean and variance:
# 220590.63648834018 15293985404.954216
# Room mean and variance:
# 3.001371742112483 0.7101629509036916
# Surface Area mean and variance:
# 110.10288065843622 4212.97154388821
# Bedroom mean and variance:
# 1.615912208504801 0.5555706296447037

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# TODO

# Fuenlabrada
pop1_prices = subset_ds[subset_ds['level5'].isin(["Fuenlabrada"])]
pop1_max_price_index = subset_ds[subset_ds['level5'].isin(["Fuenlabrada"])]['price'].idxmax()
pop1_max_price= pop1_prices.loc[pop1_max_price_index, 'price']
pop1_max_address = pop1_prices.loc[pop1_max_price_index, 'address']
print(pop1_max_price, pop1_max_address)

#Leganés
pop2_prices = subset_ds[subset_ds['level5'].isin(["Leganés"])]
pop2_max_price_index = subset_ds[subset_ds['level5'].isin(["Leganés"])]['price'].idxmax()
pop2_max_price= pop2_prices.loc[pop2_max_price_index, 'price']
pop2_max_address = pop2_prices.loc[pop2_max_price_index, 'address']
print(pop2_max_price, pop2_max_address)

#Getafe
pop3_prices = subset_ds[subset_ds['level5'].isin(["Getafe"])]
pop3_max_price_index = subset_ds[subset_ds['level5'].isin(["Getafe"])]['price'].idxmax()
pop3_max_price= pop3_prices.loc[pop3_max_price_index, 'price']
pop3_max_address = pop3_prices.loc[pop3_max_price_index, 'address']
print(pop3_max_price, pop3_max_address)

#Alcorcon
pop4_prices = subset_ds[subset_ds['level5'].isin(["Alcorcón"])]
pop4_max_price_index = subset_ds[subset_ds['level5'].isin(["Alcorcón"])]['price'].idxmax()
pop4_max_price= pop4_prices.loc[pop4_max_price_index, 'price']
pop4_max_address = pop4_prices.loc[pop4_max_price_index, 'address']
print(pop4_max_price, pop4_max_address)
# Out:
# 490000 Calle de Paulo Freire, 5, Fuenlabrada
# 650000 Avenida Reina Sofía, Leganés
# 1050000 Getafe
# 950000 Alcorcón

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# TODO
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
subset_ds_scaler = scaler.fit_transform(subset_ds[['price']])
print(subset_ds_scaler)
colors = {'Fuenlabrada': 'red', 'Leganés': 'blue', 'Getafe': 'green', 'Alcorcón': 'purple'}
subset_ds['normalized prices'] = subset_ds_scaler
plt.figure(figsize=(20,20))
for population in subset_ds['level5'].unique():
    plt.hist(subset_ds[subset_ds['level5']== population]['normalized prices'] , alpha = 0.6 , label = population , color = colors[population])
plt.xlabel('Normalized Prices')
plt.title('Normalized Prices Distribution')
plt.legend()
plt.show()
# Out:
# [[-1.06478697e+00]
#  [ 8.04386979e-01]
#  [ 1.65401150e+00]
#  [ 1.53008180e-01]
#  [ 5.61637116e-01]
#  [-1.29944517e+00]
#  [-6.52112199e-01]
#  [-2.96079067e-01]
#  [-4.60582557e-01]
#  [-3.28526632e-01]
#  [-6.73150520e-01]
#  [-6.88524678e-01]
#  [-4.46672990e-01]
#  [-9.76587849e-01]
#  [ 3.02703929e-01]
#  [-6.68295523e-01]
#  [ 1.37083569e+00]
#  [ 2.29878970e-01]
#  [ 1.89676136e+00]
#  [-4.05316505e-01]
#  [-4.49820646e-01]
#  [-7.73487130e-01]
#  [-4.09362336e-01]
#  [-6.92651426e-01]
#  [-7.16845496e-01]
#  [-9.55549528e-01]
#  [-4.09362336e-01]
#  [ 1.69446981e+00]
#  [ 5.36552964e-01]
#  [-4.49820646e-01]
#  [-8.13945441e-01]
#  [ 1.24942839e+00]
#  [-4.49901563e-01]
#  [ 1.04458207e-01]
#  [ 3.18078087e-01]
#  [ 2.05859460e+00]
#  [-9.76587849e-01]
#  [-8.26082934e-01]
#  [-9.15091217e-01]
#  [-8.30937931e-01]
#  [ 1.25752006e+00]
#  [-6.68295523e-01]
#  [ 1.37080333e+00]
#  [ 2.13951123e+00]
#  [ 6.34462075e-01]
#  [-8.14754607e-01]
#  [-8.22037103e-01]
# ...

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO

getafe_mean_pps = subset_ds[subset_ds['level5']=="Getafe"]['pps'].mean()
alcorcon_mean_pps = subset_ds[subset_ds['level5']=="Alcorcón"]['pps'].mean()
print(getafe_mean_pps, alcorcon_mean_pps)
# Out:
# 2088.189911464943 2244.5684836556106

# %% [markdown]
# Observations:
# We can see that the average price per suqare meter in the Getafe zone is significantly more accesible at 2,088.19 USD compared to that of Alcorocon at 2,224.57 USD.

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(15, 10))
for i, population in enumerate(subset_ds['level5'].unique()):
    axs[i].scatter(subset_ds[subset_ds['level5']== population]['normalized prices'] , label = population, color = colors[population])
    axs[i].xlabel('Normalized Prices')
    axs[i].title('Normalized Prices Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/realestate-datacleanup-exercise/project.ipynb Cell 56 line 3
#       <a href='vscode-notebook-cell://codespaces%2Bglorious-waddle-g44qpq5vgvp7cgpv/workspaces/realestate-datacleanup-exercise/project.ipynb#Y114sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> fig, axs = plt.subplots(nrows=4, ncols=1, figsize=(15, 10))
#       <a href='vscode-notebook-cell://codespaces%2Bglorious-waddle-g44qpq5vgvp7cgpv/workspaces/realestate-datacleanup-exercise/project.ipynb#Y114sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> for i, population in enumerate(subset_ds['level5'].unique()):
# ...

# %%
# TODO

colors = {'Fuenlabrada': 'red', 'Leganés': 'blue', 'Getafe': 'green', 'Alcorcón': 'purple'}
subset_ds_sorted = subset_ds.sort_values(by = 'normalized prices')
plt.figure(figsize=(20,20))
for population in subset_ds_sorted['level5'].unique():
    plt.hist(subset_ds[subset_ds['level5']== population]['normalized prices'] , alpha = 0.6 , label = population, color = colors[population])
plt.xlabel('Normalized Prices')
plt.title('Normalized Prices Distribution')
plt.legend()
plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps, Marker

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (40, -4.3), zoom = 8, min_zoom = 1, max_zoom = 20)
map
# Out:
# Map(center=[40, -4.3], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
subset_ds['latitude'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 729 entries, 3 to 15325
# Series name: latitude
# Non-Null Count  Dtype
# --------------  -----
# 729 non-null    object
# dtypes: object(1)
# memory usage: 11.4+ KB

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
for index,row in subset_ds.iterrows():
    row['latitude'] = row['latitude'].replace(',','.')
    row['longitude'] = row['longitude'].replace(',','.')
    marker = Marker(location=(float(row['latitude']), float(row['longitude'])), draggable=False)
    map.add_layer(marker)
map
# Out:
# Map(bottom=24951.0, center=[40.250184183819854, -4.010119801701431], controls=(ZoomControl(options=['position'…
